# %% [markdown]
# ## Numpy Tutorials

# %%
import numpy as np

# %%
lst = [1,2,3,4,5]
arry = np.array(lst)

# %%
print(arry)
# Out:
# [1 2 3 4 5]

# %%
arry.shape
# Out:
# (5,)

# %%
## Multinested array
my_lst1=[1,2,3,4,5]
my_lst2=[2,3,4,5,6]
my_lst3=[9,7,6,8,9]

arr=np.array([my_lst1,my_lst2,my_lst3])

# %%
print(arr)
# Out:
# [[1 2 3 4 5]
#  [2 3 4 5 6]
#  [9 7 6 8 9]]

# %%
arr1 = arr.reshape(5,3)

# %%
print(arr)
# Out:
# [[1 2 3 4 5]
#  [2 3 4 5 6]
#  [9 7 6 8 9]]

# %%
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 2]
#  [3 4 5]
#  [6 9 7]
#  [6 8 9]]

# %%
arry[3]
# Out:
# 4

# %%
arr[0:2, 0:3]
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
arr[1:4, 2:4]
# Out:
# array([[4, 5],
#        [6, 8]])

# %%
arr[1:2, 1:4]
# Out:
# array([[3, 4, 5]])

# %%
arr2 = np.arange(0,9)

# %%
print(arr2)
# Out:
# [0 1 2 3 4 5 6 7 8]

# %%
arr3 = np.linspace(1,10,5)

# %%
arr3
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
arry
# Out:
# array([1, 2, 3, 4, 5])

# %%
arry[3: ] = 100
print(arry)
# Out:
# [  1   2   3 100 100]

# %%
aar = arry.copy()
aar2 = arry #changes original object values

# %%
aar[3: ] = 500
print(aar)
# Out:
# [  1   2   3 500 500]

# %%
print(arry)
aar2[3: ] = 200
print(aar2)
print(aar)
# Out:
# [  1   2   3 200 200]
# [  1   2   3 200 200]
# [  1   2   3 500 500]

# %%
arry[arry<2]
# Out:
# array([1])
